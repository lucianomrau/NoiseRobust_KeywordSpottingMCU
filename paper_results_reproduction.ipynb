# %% [markdown]
# This notebook reproduces the results of Figure 5 from the paper "Sub-mW Keyword Spotting on an MCU: Analog Binary Feature Extration and Bynary Neural Networks" by Cerutti et al. (2022) published on IEEE Transactions on Circuits and Systems.
#
# The first three models are here trained and tested:
# - Baseline (full precision model).
# - Binary weights.
# - BNN (binary weights and binary activations).
#
# Results obtained are even better than in the paper.

# %%
from spectrogram import SpectrogramSpeechCommandDataset
from speech_command_dataset import SpeechCommandDataset
import matplotlib.pyplot as plt
import torch, torchaudio
from torch.utils.data import DataLoader, TensorDataset
from torchsummary import summary
from torchModel import train_model, test_model_with_confusion_matrix
from ModelsArchitecture import BinarizedInputNetwork, ConvNet , BinarizedWeightNetwork
from functions import load_in_memory

# %%
DATASET_PATH = '/home/luciano/Downloads/speech_commands_v0.02/'
TESTSET_PATH = '/home/luciano/Downloads/speech_commands_test_set_v0.02/'

KEYWORDS =  list(set(['yes', 'no', 'up', 'down', 'left', 'right', 'on', 'off', 'stop', 'go'] + ['unknown', 'silence']))

# Check for GPU availability and use it if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Using device: {device}')

SAMPLE_RATE = 16000
N_MELS = 64
N_FFT = 512
POWER = 2.0
F_MIN = 50.0
F_MAX = 7500.0
HOP_LENGTH=round(SAMPLE_RATE*0.01)
WIN_LENGTH=round(SAMPLE_RATE*0.025)
DURATION_SEC = 1.0

mel_spectrogram = torchaudio.transforms.MelSpectrogram(
            n_mels=N_MELS,
            n_fft=N_FFT, 
            hop_length=HOP_LENGTH,
            win_length=WIN_LENGTH,
            f_min=F_MIN,
            f_max=F_MAX,
            power=POWER,
            sample_rate=SAMPLE_RATE,
        )

dataset = SpectrogramSpeechCommandDataset(
    audio_dataset_path=DATASET_PATH,
    audio_test_path=TESTSET_PATH,
    transformation=mel_spectrogram,
    sample_rate= SAMPLE_RATE,
    duration_seconds = DURATION_SEC,
    keywords=KEYWORDS,
    device = device
)
# Out:
# Using device: cuda

# %% [markdown]
# ## Load audio files

# %%
test_set_waveform = dataset.get_testset()
validation_set_waveform = dataset.get_validationset()
train_set_waveform = dataset.get_trainset()

# %% [markdown]
# # MEL Spectrogram

# %%
test_set = dataset.get_spectrum_testset()
train_set = dataset.get_spectrum_trainset()
validation_set = dataset.get_spectrum_validationset()

# %%
def plot_waveform(waveform, sr, xlabel,ylabel,title="Waveform", ax=None,):
    waveform = waveform.numpy()

    num_channels, num_frames = waveform.shape
    time_axis = torch.arange(0, num_frames) / sr

    if ax is None:
        _, ax = plt.subplots(num_channels, 1)
    ax.plot(time_axis, waveform[0], linewidth=1)
    ax.grid(True)
    ax.set_xlim([0, time_axis[-1]])
    ax.set_title(title)
    ax.set_ylabel(ylabel)
    ax.set_xlabel(xlabel)


def plot_spectrogram(specgram, title=None, ylabel="freq_bin", ax=None):
    if ax is None:
        _, ax = plt.subplots(1, 1)
    if title is not None:
        ax.set_title(title)
    ax.set_ylabel(ylabel)
    ax.imshow((specgram), origin="lower", aspect="auto", interpolation="nearest")


fig, axs = plt.subplots(2, 1)
plot_waveform(train_set_waveform[0][0].cpu(), SAMPLE_RATE, title="Original waveform", 
              ax=axs[0],ylabel="Amplitude",xlabel="Time")
plot_spectrogram(train_set[0][0][0].cpu(), ax=axs[1],title="MelSpectrogram - torchaudio", ylabel="mel freq")
fig.tight_layout()

# %% [markdown]
# # train models

# %%
BATCH_SIZE = 16
EPOCHS = 50
LEARNING_RATE = 0.001


all_data , all_labels = load_in_memory(train_set)
train_tensor = TensorDataset(torch.stack(all_data) ,torch.tensor(all_labels) )
all_data , all_labels = load_in_memory(validation_set)
val_tensor = TensorDataset(torch.stack(all_data) ,torch.tensor(all_labels) )
all_data , all_labels = load_in_memory(test_set)
test_tensor = TensorDataset(torch.stack(all_data) ,torch.tensor(all_labels) )

train_loader = DataLoader(train_tensor, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_tensor, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_tensor, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# ## Build Full precision model

# %%
model = ConvNet().to(device)
summary(model,(1,101,64),batch_size=BATCH_SIZE)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [16, 64, 51, 32]             640
#        BatchNorm2d-2           [16, 64, 51, 32]             128
#             Conv2d-3          [16, 128, 51, 32]          73,856
#        BatchNorm2d-4          [16, 128, 51, 32]             256
#             Conv2d-5          [16, 128, 26, 16]         147,584
#        BatchNorm2d-6          [16, 128, 26, 16]             256
#             Conv2d-7          [16, 192, 26, 16]         221,376
#        BatchNorm2d-8          [16, 192, 26, 16]             384
#             Conv2d-9          [16, 192, 26, 16]          37,056
#       BatchNorm2d-10          [16, 192, 26, 16]             384
#            Conv2d-11           [16, 12, 26, 16]           2,316
#       BatchNorm2d-12           [16, 12, 26, 16]              24
# AdaptiveAvgPool2d-13             [16, 12, 1, 1]               0
# ================================================================
# Total params: 484,260
# Trainable params: 484,260
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.39
# Forward/backward pass size (MB): 129.72
# Params size (MB): 1.85
# Estimated Total Size (MB): 131.96
# ----------------------------------------------------------------

# %%
train_model(train_loader, val_loader, model,device,LEARNING_RATE,num_epochs=50)
torch.save(model.state_dict(), "./models/full_precision.pth")
# Out:
# Epoch 1/50, Train Loss: 1.7586, Train Acc: 0.6148, Val Loss: 1.0755, Val Acc: 0.8334, Learning Rate: 0.001000
# Epoch 2/50, Train Loss: 0.9979, Train Acc: 0.8354, Val Loss: 0.6506, Val Acc: 0.8665, Learning Rate: 0.001000
# Epoch 3/50, Train Loss: 0.6729, Train Acc: 0.8797, Val Loss: 0.4087, Val Acc: 0.9210, Learning Rate: 0.001000
# Epoch 4/50, Train Loss: 0.5118, Train Acc: 0.9004, Val Loss: 0.3313, Val Acc: 0.9334, Learning Rate: 0.001000
# Epoch 5/50, Train Loss: 0.4101, Train Acc: 0.9181, Val Loss: 0.2816, Val Acc: 0.9358, Learning Rate: 0.001000
# Epoch 6/50, Train Loss: 0.3429, Train Acc: 0.9282, Val Loss: 0.2567, Val Acc: 0.9347, Learning Rate: 0.001000
# Epoch 7/50, Train Loss: 0.2928, Train Acc: 0.9386, Val Loss: 0.2447, Val Acc: 0.9390, Learning Rate: 0.001000
# Epoch 8/50, Train Loss: 0.2554, Train Acc: 0.9464, Val Loss: 0.2026, Val Acc: 0.9480, Learning Rate: 0.001000
# Epoch 9/50, Train Loss: 0.2229, Train Acc: 0.9537, Val Loss: 0.2015, Val Acc: 0.9487, Learning Rate: 0.001000
# Epoch 10/50, Train Loss: 0.1966, Train Acc: 0.9602, Val Loss: 0.1873, Val Acc: 0.9514, Learning Rate: 0.001000
# Epoch 11/50, Train Loss: 0.1734, Train Acc: 0.9653, Val Loss: 0.1769, Val Acc: 0.9525, Learning Rate: 0.001000
# Epoch 12/50, Train Loss: 0.1540, Train Acc: 0.9698, Val Loss: 0.1724, Val Acc: 0.9491, Learning Rate: 0.001000
# Epoch 13/50, Train Loss: 0.1370, Train Acc: 0.9733, Val Loss: 0.1875, Val Acc: 0.9435, Learning Rate: 0.001000
# Epoch 14/50, Train Loss: 0.1248, Train Acc: 0.9757, Val Loss: 0.2056, Val Acc: 0.9417, Learning Rate: 0.001000
# Epoch 15/50, Train Loss: 0.1114, Train Acc: 0.9797, Val Loss: 0.1586, Val Acc: 0.9527, Learning Rate: 0.001000
# Epoch 16/50, Train Loss: 0.0993, Train Acc: 0.9827, Val Loss: 0.1909, Val Acc: 0.9446, Learning Rate: 0.001000
# Epoch 17/50, Train Loss: 0.0871, Train Acc: 0.9858, Val Loss: 0.1782, Val Acc: 0.9511, Learning Rate: 0.001000
# Epoch 18/50, Train Loss: 0.0797, Train Acc: 0.9871, Val Loss: 0.1791, Val Acc: 0.9511, Learning Rate: 0.001000
# Epoch 19/50, Train Loss: 0.0732, Train Acc: 0.9884, Val Loss: 0.1811, Val Acc: 0.9437, Learning Rate: 0.001000
# Epoch 20/50, Train Loss: 0.0609, Train Acc: 0.9914, Val Loss: 0.1548, Val Acc: 0.9538, Learning Rate: 0.001000
# Epoch 21/50, Train Loss: 0.0591, Train Acc: 0.9915, Val Loss: 0.1853, Val Acc: 0.9482, Learning Rate: 0.001000
# Epoch 22/50, Train Loss: 0.0557, Train Acc: 0.9921, Val Loss: 0.1963, Val Acc: 0.9403, Learning Rate: 0.001000
# Epoch 23/50, Train Loss: 0.0502, Train Acc: 0.9932, Val Loss: 0.2091, Val Acc: 0.9392, Learning Rate: 0.001000
# Epoch 24/50, Train Loss: 0.0461, Train Acc: 0.9937, Val Loss: 0.1873, Val Acc: 0.9473, Learning Rate: 0.001000
# Epoch 25/50, Train Loss: 0.0419, Train Acc: 0.9950, Val Loss: 0.2096, Val Acc: 0.9340, Learning Rate: 0.001000
# Epoch 26/50, Train Loss: 0.0403, Train Acc: 0.9945, Val Loss: 0.1923, Val Acc: 0.9417, Learning Rate: 0.001000
# Epoch 27/50, Train Loss: 0.0375, Train Acc: 0.9950, Val Loss: 0.1805, Val Acc: 0.9455, Learning Rate: 0.001000
# Epoch 28/50, Train Loss: 0.0340, Train Acc: 0.9963, Val Loss: 0.1770, Val Acc: 0.9482, Learning Rate: 0.001000
# Epoch 29/50, Train Loss: 0.0321, Train Acc: 0.9959, Val Loss: 0.1728, Val Acc: 0.9484, Learning Rate: 0.001000
# Epoch 30/50, Train Loss: 0.0303, Train Acc: 0.9967, Val Loss: 0.1695, Val Acc: 0.9532, Learning Rate: 0.001000
# Epoch 31/50, Train Loss: 0.0274, Train Acc: 0.9969, Val Loss: 0.1938, Val Acc: 0.9428, Learning Rate: 0.000100
# Epoch 32/50, Train Loss: 0.0170, Train Acc: 0.9986, Val Loss: 0.1491, Val Acc: 0.9568, Learning Rate: 0.000100
# Epoch 33/50, Train Loss: 0.0109, Train Acc: 0.9997, Val Loss: 0.1530, Val Acc: 0.9554, Learning Rate: 0.000100
# Epoch 34/50, Train Loss: 0.0094, Train Acc: 0.9998, Val Loss: 0.1508, Val Acc: 0.9563, Learning Rate: 0.000100
# Epoch 35/50, Train Loss: 0.0085, Train Acc: 0.9999, Val Loss: 0.1508, Val Acc: 0.9577, Learning Rate: 0.000100
# Epoch 36/50, Train Loss: 0.0081, Train Acc: 0.9998, Val Loss: 0.1494, Val Acc: 0.9554, Learning Rate: 0.000100
# Epoch 37/50, Train Loss: 0.0072, Train Acc: 0.9999, Val Loss: 0.1485, Val Acc: 0.9548, Learning Rate: 0.000100
# Epoch 38/50, Train Loss: 0.0072, Train Acc: 0.9998, Val Loss: 0.1507, Val Acc: 0.9575, Learning Rate: 0.000100
# Epoch 39/50, Train Loss: 0.0067, Train Acc: 0.9999, Val Loss: 0.1581, Val Acc: 0.9532, Learning Rate: 0.000100
# Epoch 40/50, Train Loss: 0.0065, Train Acc: 0.9999, Val Loss: 0.1541, Val Acc: 0.9548, Learning Rate: 0.000100
# Epoch 41/50, Train Loss: 0.0059, Train Acc: 0.9999, Val Loss: 0.1497, Val Acc: 0.9570, Learning Rate: 0.000100
# Epoch 42/50, Train Loss: 0.0061, Train Acc: 0.9998, Val Loss: 0.1533, Val Acc: 0.9563, Learning Rate: 0.000100
# Epoch 43/50, Train Loss: 0.0058, Train Acc: 0.9999, Val Loss: 0.1591, Val Acc: 0.9538, Learning Rate: 0.000100
# Epoch 44/50, Train Loss: 0.0056, Train Acc: 0.9999, Val Loss: 0.1528, Val Acc: 0.9561, Learning Rate: 0.000100
# Epoch 45/50, Train Loss: 0.0051, Train Acc: 1.0000, Val Loss: 0.1552, Val Acc: 0.9543, Learning Rate: 0.000100
# Epoch 46/50, Train Loss: 0.0054, Train Acc: 0.9998, Val Loss: 0.1541, Val Acc: 0.9559, Learning Rate: 0.000100
# Epoch 47/50, Train Loss: 0.0051, Train Acc: 0.9999, Val Loss: 0.1562, Val Acc: 0.9538, Learning Rate: 0.000100
# Epoch 48/50, Train Loss: 0.0048, Train Acc: 0.9999, Val Loss: 0.1511, Val Acc: 0.9557, Learning Rate: 0.000010
# Epoch 49/50, Train Loss: 0.0046, Train Acc: 0.9999, Val Loss: 0.1522, Val Acc: 0.9557, Learning Rate: 0.000010
# Epoch 50/50, Train Loss: 0.0043, Train Acc: 1.0000, Val Loss: 0.1513, Val Acc: 0.9577, Learning Rate: 0.000010

# %%
test_model_with_confusion_matrix(test_loader,model,KEYWORDS,device)
# Out:
# Test Accuracy: 0.9601

# %% [markdown]
# ## Build BWN model

# %%
input_shape = (1, 64, 101)  # Example input shape, adjust as needed
num_classes = len(KEYWORDS)  # Example number of classes, adjust as needed
model = BinarizedWeightNetwork(input_shape, num_classes).to(device)

# %%
summary(model,(1,101,64),batch_size=BATCH_SIZE)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [16, 64, 51, 32]             640
#        BatchNorm2d-2           [16, 64, 51, 32]             128
# _BinarizedWeightConv2D-3          [16, 128, 51, 32]               0
#        BatchNorm2d-4          [16, 128, 51, 32]             256
# _BinarizedWeightConv2D-5          [16, 128, 26, 16]               0
#        BatchNorm2d-6          [16, 128, 26, 16]             256
# _BinarizedWeightConv2D-7          [16, 192, 26, 16]               0
#        BatchNorm2d-8          [16, 192, 26, 16]             384
# _BinarizedWeightConv2D-9          [16, 192, 26, 16]               0
#       BatchNorm2d-10          [16, 192, 26, 16]             384
#            Conv2d-11           [16, 12, 26, 16]           2,316
# AdaptiveAvgPool2d-12             [16, 12, 1, 1]               0
#            Linear-13                   [16, 12]             156
# ================================================================
# Total params: 4,520
# Trainable params: 4,520
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.39
# Forward/backward pass size (MB): 129.11
# Params size (MB): 0.02
# Estimated Total Size (MB): 129.52
# ----------------------------------------------------------------

# %%
train_model(train_loader, val_loader, model,device,
            learning_rate=LEARNING_RATE,num_epochs=EPOCHS)
# Out:
# Epoch 1/50, Train Loss: 2.2852, Train Acc: 0.3327, Val Loss: 2.1731, Val Acc: 0.4557, Learning Rate: 0.001000
# Epoch 2/50, Train Loss: 2.0361, Train Acc: 0.6005, Val Loss: 2.0035, Val Acc: 0.6256, Learning Rate: 0.001000
# Epoch 3/50, Train Loss: 1.8923, Train Acc: 0.7436, Val Loss: 1.8123, Val Acc: 0.8165, Learning Rate: 0.001000
# Epoch 4/50, Train Loss: 1.8363, Train Acc: 0.7930, Val Loss: 1.8951, Val Acc: 0.7276, Learning Rate: 0.001000
# Epoch 5/50, Train Loss: 1.8028, Train Acc: 0.8252, Val Loss: 1.7606, Val Acc: 0.8685, Learning Rate: 0.001000
# Epoch 6/50, Train Loss: 1.7761, Train Acc: 0.8499, Val Loss: 1.7533, Val Acc: 0.8703, Learning Rate: 0.001000
# Epoch 7/50, Train Loss: 1.7570, Train Acc: 0.8690, Val Loss: 1.7349, Val Acc: 0.8904, Learning Rate: 0.001000
# Epoch 8/50, Train Loss: 1.7450, Train Acc: 0.8801, Val Loss: 1.7252, Val Acc: 0.8989, Learning Rate: 0.001000
# Epoch 9/50, Train Loss: 1.7331, Train Acc: 0.8909, Val Loss: 1.7601, Val Acc: 0.8627, Learning Rate: 0.001000
# Epoch 10/50, Train Loss: 1.7266, Train Acc: 0.8970, Val Loss: 1.7363, Val Acc: 0.8845, Learning Rate: 0.001000
# Epoch 11/50, Train Loss: 1.7183, Train Acc: 0.9048, Val Loss: 1.7052, Val Acc: 0.9176, Learning Rate: 0.001000
# Epoch 12/50, Train Loss: 1.7154, Train Acc: 0.9074, Val Loss: 1.7345, Val Acc: 0.8874, Learning Rate: 0.001000
# Epoch 13/50, Train Loss: 1.7087, Train Acc: 0.9147, Val Loss: 1.7289, Val Acc: 0.8944, Learning Rate: 0.001000
# Epoch 14/50, Train Loss: 1.7034, Train Acc: 0.9190, Val Loss: 1.6965, Val Acc: 0.9250, Learning Rate: 0.001000
# Epoch 15/50, Train Loss: 1.7006, Train Acc: 0.9209, Val Loss: 1.6912, Val Acc: 0.9302, Learning Rate: 0.001000
# Epoch 16/50, Train Loss: 1.6953, Train Acc: 0.9263, Val Loss: 1.6991, Val Acc: 0.9226, Learning Rate: 0.001000
# Epoch 17/50, Train Loss: 1.6928, Train Acc: 0.9288, Val Loss: 1.6985, Val Acc: 0.9237, Learning Rate: 0.001000
# Epoch 18/50, Train Loss: 1.6900, Train Acc: 0.9313, Val Loss: 1.6967, Val Acc: 0.9244, Learning Rate: 0.001000
# Epoch 19/50, Train Loss: 1.6868, Train Acc: 0.9348, Val Loss: 1.6925, Val Acc: 0.9273, Learning Rate: 0.001000
# Epoch 20/50, Train Loss: 1.6855, Train Acc: 0.9352, Val Loss: 1.7069, Val Acc: 0.9124, Learning Rate: 0.001000
# Epoch 21/50, Train Loss: 1.6808, Train Acc: 0.9407, Val Loss: 1.6900, Val Acc: 0.9298, Learning Rate: 0.001000
# Epoch 22/50, Train Loss: 1.6822, Train Acc: 0.9388, Val Loss: 1.6921, Val Acc: 0.9259, Learning Rate: 0.001000
# Epoch 23/50, Train Loss: 1.6787, Train Acc: 0.9426, Val Loss: 1.6863, Val Acc: 0.9338, Learning Rate: 0.001000
# Epoch 24/50, Train Loss: 1.6767, Train Acc: 0.9441, Val Loss: 1.6854, Val Acc: 0.9358, Learning Rate: 0.001000
# Epoch 25/50, Train Loss: 1.6757, Train Acc: 0.9454, Val Loss: 1.6859, Val Acc: 0.9343, Learning Rate: 0.001000
# Epoch 26/50, Train Loss: 1.6716, Train Acc: 0.9496, Val Loss: 1.7121, Val Acc: 0.9063, Learning Rate: 0.001000
# Epoch 27/50, Train Loss: 1.6731, Train Acc: 0.9479, Val Loss: 1.6790, Val Acc: 0.9415, Learning Rate: 0.001000
# Epoch 28/50, Train Loss: 1.6707, Train Acc: 0.9499, Val Loss: 1.6929, Val Acc: 0.9262, Learning Rate: 0.001000
# Epoch 29/50, Train Loss: 1.6697, Train Acc: 0.9508, Val Loss: 1.6814, Val Acc: 0.9374, Learning Rate: 0.001000
# Epoch 30/50, Train Loss: 1.6682, Train Acc: 0.9525, Val Loss: 1.6915, Val Acc: 0.9280, Learning Rate: 0.001000
# Epoch 31/50, Train Loss: 1.6679, Train Acc: 0.9525, Val Loss: 1.6903, Val Acc: 0.9282, Learning Rate: 0.001000
# Epoch 32/50, Train Loss: 1.6664, Train Acc: 0.9538, Val Loss: 1.6781, Val Acc: 0.9424, Learning Rate: 0.001000
# Epoch 33/50, Train Loss: 1.6653, Train Acc: 0.9552, Val Loss: 1.6780, Val Acc: 0.9417, Learning Rate: 0.001000
# Epoch 34/50, Train Loss: 1.6636, Train Acc: 0.9564, Val Loss: 1.6939, Val Acc: 0.9264, Learning Rate: 0.001000
# Epoch 35/50, Train Loss: 1.6620, Train Acc: 0.9585, Val Loss: 1.6867, Val Acc: 0.9340, Learning Rate: 0.001000
# Epoch 36/50, Train Loss: 1.6623, Train Acc: 0.9578, Val Loss: 1.6852, Val Acc: 0.9334, Learning Rate: 0.001000
# Epoch 37/50, Train Loss: 1.6627, Train Acc: 0.9570, Val Loss: 1.6795, Val Acc: 0.9403, Learning Rate: 0.001000
# Epoch 38/50, Train Loss: 1.6612, Train Acc: 0.9594, Val Loss: 1.6859, Val Acc: 0.9345, Learning Rate: 0.001000
# Epoch 39/50, Train Loss: 1.6594, Train Acc: 0.9609, Val Loss: 1.6903, Val Acc: 0.9271, Learning Rate: 0.001000
# Epoch 40/50, Train Loss: 1.6592, Train Acc: 0.9611, Val Loss: 1.6930, Val Acc: 0.9266, Learning Rate: 0.001000
# Epoch 41/50, Train Loss: 1.6579, Train Acc: 0.9621, Val Loss: 1.6851, Val Acc: 0.9347, Learning Rate: 0.001000
# Epoch 42/50, Train Loss: 1.6560, Train Acc: 0.9640, Val Loss: 1.6815, Val Acc: 0.9383, Learning Rate: 0.001000
# Epoch 43/50, Train Loss: 1.6583, Train Acc: 0.9618, Val Loss: 1.6871, Val Acc: 0.9309, Learning Rate: 0.001000
# Epoch 44/50, Train Loss: 1.6568, Train Acc: 0.9629, Val Loss: 1.7095, Val Acc: 0.9102, Learning Rate: 0.000100
# Epoch 45/50, Train Loss: 1.6432, Train Acc: 0.9768, Val Loss: 1.6703, Val Acc: 0.9496, Learning Rate: 0.000100
# Epoch 46/50, Train Loss: 1.6388, Train Acc: 0.9811, Val Loss: 1.6694, Val Acc: 0.9502, Learning Rate: 0.000100
# Epoch 47/50, Train Loss: 1.6375, Train Acc: 0.9827, Val Loss: 1.6704, Val Acc: 0.9482, Learning Rate: 0.000100
# Epoch 48/50, Train Loss: 1.6367, Train Acc: 0.9831, Val Loss: 1.6687, Val Acc: 0.9507, Learning Rate: 0.000100
# Epoch 49/50, Train Loss: 1.6357, Train Acc: 0.9842, Val Loss: 1.6689, Val Acc: 0.9502, Learning Rate: 0.000100
# Epoch 50/50, Train Loss: 1.6351, Train Acc: 0.9849, Val Loss: 1.6699, Val Acc: 0.9500, Learning Rate: 0.000100

# %%
torch.save(model.state_dict(), "./models/BinaryWeights.pth")
test_model_with_confusion_matrix(test_loader,model,KEYWORDS,device)
# Out:
# Test Accuracy: 0.9534

# %% [markdown]
# ## full binary model (weights and activations)

# %%
input_shape = (1, 64, 101)  # Example input shape, adjust as needed
num_classes = len(KEYWORDS)  # Example number of classes, adjust as needed

model = BinarizedInputNetwork(input_shape, num_classes).to(device)
summary(model,(1,101,64),batch_size=BATCH_SIZE)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [16, 64, 51, 32]             640
#        BatchNorm2d-2           [16, 64, 51, 32]             128
#    _BinarizeConv2d-3          [16, 128, 51, 32]          73,728
#        BatchNorm2d-4          [16, 128, 51, 32]             256
#    _BinarizeConv2d-5          [16, 128, 26, 16]         147,456
#        BatchNorm2d-6          [16, 128, 26, 16]             256
#    _BinarizeConv2d-7          [16, 192, 26, 16]         221,184
#        BatchNorm2d-8          [16, 192, 26, 16]             384
#    _BinarizeConv2d-9          [16, 192, 26, 16]          36,864
#       BatchNorm2d-10          [16, 192, 26, 16]             384
#            Conv2d-11           [16, 12, 26, 16]           2,316
# AdaptiveAvgPool2d-12             [16, 12, 1, 1]               0
#            Linear-13                   [16, 12]             156
# ================================================================
# Total params: 483,752
# Trainable params: 483,752
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.39
# Forward/backward pass size (MB): 129.11
# Params size (MB): 1.85
# Estimated Total Size (MB): 131.35
# ----------------------------------------------------------------

# %%
train_model(train_loader, val_loader, model,device,LEARNING_RATE,num_epochs=EPOCHS)
torch.save(model.state_dict(), "./models/full_binary_model.pth")
# Out:
# Epoch 1/50, Train Loss: 2.3935, Train Acc: 0.2047, Val Loss: 2.4507, Val Acc: 0.1571, Learning Rate: 0.001000
# Epoch 2/50, Train Loss: 2.3196, Train Acc: 0.2942, Val Loss: 2.2544, Val Acc: 0.3751, Learning Rate: 0.001000
# Epoch 3/50, Train Loss: 2.2030, Train Acc: 0.4199, Val Loss: 2.1334, Val Acc: 0.4842, Learning Rate: 0.001000
# Epoch 4/50, Train Loss: 2.1199, Train Acc: 0.5075, Val Loss: 2.0705, Val Acc: 0.5608, Learning Rate: 0.001000
# Epoch 5/50, Train Loss: 2.0434, Train Acc: 0.5842, Val Loss: 2.0140, Val Acc: 0.6083, Learning Rate: 0.001000
# Epoch 6/50, Train Loss: 1.9909, Train Acc: 0.6347, Val Loss: 1.9747, Val Acc: 0.6499, Learning Rate: 0.001000
# Epoch 7/50, Train Loss: 1.9296, Train Acc: 0.6982, Val Loss: 1.9225, Val Acc: 0.7044, Learning Rate: 0.001000
# Epoch 8/50, Train Loss: 1.8636, Train Acc: 0.7653, Val Loss: 1.8203, Val Acc: 0.8050, Learning Rate: 0.001000
# Epoch 9/50, Train Loss: 1.8360, Train Acc: 0.7907, Val Loss: 1.8783, Val Acc: 0.7447, Learning Rate: 0.001000
# Epoch 10/50, Train Loss: 1.8173, Train Acc: 0.8082, Val Loss: 1.7968, Val Acc: 0.8280, Learning Rate: 0.001000
# Epoch 11/50, Train Loss: 1.8016, Train Acc: 0.8226, Val Loss: 1.8042, Val Acc: 0.8167, Learning Rate: 0.001000
# Epoch 12/50, Train Loss: 1.7898, Train Acc: 0.8339, Val Loss: 1.7784, Val Acc: 0.8456, Learning Rate: 0.001000
# Epoch 13/50, Train Loss: 1.7822, Train Acc: 0.8410, Val Loss: 1.7778, Val Acc: 0.8442, Learning Rate: 0.001000
# Epoch 14/50, Train Loss: 1.7739, Train Acc: 0.8497, Val Loss: 1.7628, Val Acc: 0.8593, Learning Rate: 0.001000
# Epoch 15/50, Train Loss: 1.7681, Train Acc: 0.8545, Val Loss: 1.7803, Val Acc: 0.8444, Learning Rate: 0.001000
# Epoch 16/50, Train Loss: 1.7632, Train Acc: 0.8593, Val Loss: 1.7491, Val Acc: 0.8719, Learning Rate: 0.001000
# Epoch 17/50, Train Loss: 1.7554, Train Acc: 0.8668, Val Loss: 1.7506, Val Acc: 0.8717, Learning Rate: 0.001000
# Epoch 18/50, Train Loss: 1.7491, Train Acc: 0.8738, Val Loss: 1.7464, Val Acc: 0.8757, Learning Rate: 0.001000
# Epoch 19/50, Train Loss: 1.7430, Train Acc: 0.8790, Val Loss: 1.7360, Val Acc: 0.8861, Learning Rate: 0.001000
# Epoch 20/50, Train Loss: 1.7404, Train Acc: 0.8813, Val Loss: 1.7314, Val Acc: 0.8906, Learning Rate: 0.001000
# Epoch 21/50, Train Loss: 1.7370, Train Acc: 0.8834, Val Loss: 1.7438, Val Acc: 0.8775, Learning Rate: 0.001000
# Epoch 22/50, Train Loss: 1.7372, Train Acc: 0.8841, Val Loss: 1.7171, Val Acc: 0.9057, Learning Rate: 0.001000
# Epoch 23/50, Train Loss: 1.7337, Train Acc: 0.8869, Val Loss: 1.7635, Val Acc: 0.8550, Learning Rate: 0.001000
# Epoch 24/50, Train Loss: 1.7323, Train Acc: 0.8883, Val Loss: 1.7191, Val Acc: 0.9007, Learning Rate: 0.001000
# Epoch 25/50, Train Loss: 1.7294, Train Acc: 0.8920, Val Loss: 1.7247, Val Acc: 0.8960, Learning Rate: 0.001000
# Epoch 26/50, Train Loss: 1.7264, Train Acc: 0.8936, Val Loss: 1.7153, Val Acc: 0.9048, Learning Rate: 0.001000
# Epoch 27/50, Train Loss: 1.7261, Train Acc: 0.8957, Val Loss: 1.7221, Val Acc: 0.8985, Learning Rate: 0.001000
# Epoch 28/50, Train Loss: 1.7229, Train Acc: 0.8979, Val Loss: 1.7206, Val Acc: 0.8978, Learning Rate: 0.001000
# Epoch 29/50, Train Loss: 1.7239, Train Acc: 0.8961, Val Loss: 1.7159, Val Acc: 0.9052, Learning Rate: 0.001000
# Epoch 30/50, Train Loss: 1.7184, Train Acc: 0.9023, Val Loss: 1.7146, Val Acc: 0.9057, Learning Rate: 0.001000
# Epoch 31/50, Train Loss: 1.7185, Train Acc: 0.9017, Val Loss: 1.7061, Val Acc: 0.9133, Learning Rate: 0.001000
# Epoch 32/50, Train Loss: 1.7173, Train Acc: 0.9026, Val Loss: 1.7205, Val Acc: 0.8982, Learning Rate: 0.001000
# Epoch 33/50, Train Loss: 1.7175, Train Acc: 0.9044, Val Loss: 1.7162, Val Acc: 0.9041, Learning Rate: 0.001000
# Epoch 34/50, Train Loss: 1.7162, Train Acc: 0.9040, Val Loss: 1.7263, Val Acc: 0.8949, Learning Rate: 0.001000
# Epoch 35/50, Train Loss: 1.7202, Train Acc: 0.8997, Val Loss: 1.7081, Val Acc: 0.9111, Learning Rate: 0.001000
# Epoch 36/50, Train Loss: 1.7178, Train Acc: 0.9023, Val Loss: 1.7235, Val Acc: 0.8973, Learning Rate: 0.001000
# Epoch 37/50, Train Loss: 1.7138, Train Acc: 0.9063, Val Loss: 1.7124, Val Acc: 0.9063, Learning Rate: 0.001000
# Epoch 38/50, Train Loss: 1.7160, Train Acc: 0.9045, Val Loss: 1.7232, Val Acc: 0.8989, Learning Rate: 0.001000
# Epoch 39/50, Train Loss: 1.7140, Train Acc: 0.9068, Val Loss: 1.7186, Val Acc: 0.9003, Learning Rate: 0.001000
# Epoch 40/50, Train Loss: 1.7168, Train Acc: 0.9029, Val Loss: 1.7077, Val Acc: 0.9145, Learning Rate: 0.001000
# Epoch 41/50, Train Loss: 1.7122, Train Acc: 0.9092, Val Loss: 1.7083, Val Acc: 0.9131, Learning Rate: 0.001000
# Epoch 42/50, Train Loss: 1.7143, Train Acc: 0.9060, Val Loss: 1.7106, Val Acc: 0.9084, Learning Rate: 0.000100
# Epoch 43/50, Train Loss: 1.6997, Train Acc: 0.9204, Val Loss: 1.6987, Val Acc: 0.9203, Learning Rate: 0.000100
# Epoch 44/50, Train Loss: 1.6918, Train Acc: 0.9289, Val Loss: 1.6927, Val Acc: 0.9277, Learning Rate: 0.000100
# Epoch 45/50, Train Loss: 1.6877, Train Acc: 0.9332, Val Loss: 1.6932, Val Acc: 0.9266, Learning Rate: 0.000100
# Epoch 46/50, Train Loss: 1.6871, Train Acc: 0.9333, Val Loss: 1.6942, Val Acc: 0.9280, Learning Rate: 0.000100
# Epoch 47/50, Train Loss: 1.6861, Train Acc: 0.9345, Val Loss: 1.6982, Val Acc: 0.9228, Learning Rate: 0.000100
# Epoch 48/50, Train Loss: 1.6866, Train Acc: 0.9338, Val Loss: 1.6951, Val Acc: 0.9248, Learning Rate: 0.000100
# Epoch 49/50, Train Loss: 1.6850, Train Acc: 0.9363, Val Loss: 1.6949, Val Acc: 0.9264, Learning Rate: 0.000100
# Epoch 50/50, Train Loss: 1.6840, Train Acc: 0.9368, Val Loss: 1.6937, Val Acc: 0.9289, Learning Rate: 0.000100

# %%
test_model_with_confusion_matrix(test_loader,model,KEYWORDS,device)
# Out:
# Test Accuracy: 0.9311
